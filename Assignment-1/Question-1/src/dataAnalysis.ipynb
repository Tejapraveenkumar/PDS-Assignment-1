# %%
import pandas as pd
data=pd.read_csv(r"C:\Users\tejap\Assignment-1\Question-1\Cleaned_Data\cleaneddata.csv")
print(data)
# Out:
#    Unnamed: 0  Height  Weight  Age  Grip strength  Frailty
# 0           0    65.8     112   30       66.13860        0
# 1           1    71.5     136   19       68.34322        0
# 2           2    69.4     153   45       63.93398        0
# 3           3    68.2     142   22       61.72936        1
# 4           4    67.8     144   29       52.91088        1
# 5           5    68.7     123   50       57.32012        0
# 6           6    69.8     141   51       48.50164        1
# 7           7    70.1     136   23       44.09240        1
# 8           8    67.9     112   17       41.88778        0
# 9           9    66.8     120   39       68.34322        0

# %%
# Create a scatter plot of 'Height' vs 'Weight'
plt.scatter(data['Height'], data['Weight'], color='black')
plt.title('Height vs Weight')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %%
# Create a bar plot of 'Frailty' counts
Age_counts = data['Age'].value_counts()
plt.bar(Age_counts.index, Age_counts.values, color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
import seaborn as sns
# Create a box plot of 'Frailty' vs 'Grip strength'
sns.boxplot(x='Frailty', y='Grip strength', data=data)
plt.title('Frailty vs Grip Strength')
plt.xlabel('Frailty')
plt.ylabel('Grip Strength')
plt.show()

# %% [raw]
# Analysis Result:
#
# From above visualization, it is clearly says that Female who has more Grip Strength have less Frailty(stronger) and who has less Grip strength are suffering from Frailty(weak and delicate).
